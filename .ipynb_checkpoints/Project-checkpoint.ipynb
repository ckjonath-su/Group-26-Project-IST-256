# %%
import pandas as pd
import numpy as np
import zillow
import xmltodict
from pprint import pprint

import requests
import json 
# %matplotlib inline 

import matplotlib
import matplotlib.pyplot as plt
import plotly 
import plotly.plotly as py     
import plotly.graph_objs as go  
import cufflinks as cf
import pandas as pd
import folium
import warnings
#matplotlib.rcParams['figure.figsize'] = (20.0, 10.0) # larger figure size
warnings.filterwarnings('ignore')

# %%
import requests, json, xmltodict, requests
def housinginfo(city, state):
    url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18mobi4mvij_2doog&state=%s&city=%s&childtype=neighborhood' % (state, city)
    response = requests.get(url)
    data = response.text
    
    jsonString = json.dumps(xmltodict.parse(data), indent=4)

    with open("output.json") as f:
        datastore = json.load(f)
        
    return(datastore['RegionChildren:regionchildren'])

city = 'omaha'
state = 'ne'
housinginfo(city, state)
# Out:
# {'@xmlns:RegionChildren': 'http://www.zillow.com/static/xsd/RegionChildren.xsd',
#  '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#  '@xsi:schemaLocation': 'http://www.zillow.com/static/xsd/RegionChildren.xsd https://www.zillowstatic.com/vstatic/b20c067/static/xsd/RegionChildren.xsd',
#  'message': {'code': '0', 'text': 'Request successfully processed'},
#  'request': {'childtype': 'neighborhood', 'city': 'nc', 'state': 'mebane'},
#  'response': {'list': {'count': '1',
#    'region': {'id': '185045',
#     'latitude': '36.118497',
#     'longitude': '-79.301767',
#     'name': 'Woodlawn',
#     'url': 'http://www.zillow.com/local-info/NC-Mebane/Woodlawn/r_185045/'}},
#   'region': {'id': '29105', 'latitude': '36.13716', 'longitude': '-79.272444'},
#   'subregiontype': 'neighborhood'}}

# %%
#functions used
def originalhousinginfoaddress(city, state):
    url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18mobi4mvij_2doog&state=%s&city=%s&childtype=neighborhood' % (state, city)
    response = requests.get(url)
    datas = response.text

    jsonString = json.dumps(xmltodict.parse(datas), indent=4)

    with open("testingg.json", 'w') as f:
        f.write(jsonString)
    
    with open("testingg.json") as d:
        datastore = json.load(d)
    
    print(datastore['RegionChildren:regionchildren']['response']['list']['region'][0]['name'])
    print(datastore['RegionChildren:regionchildren']['response']['list']['region'][1]['name'])
    print(datastore['RegionChildren:regionchildren']['response']['list']['region'][2]['name'])
    print(datastore['RegionChildren:regionchildren']['response']['list']['region'][3]['name'])
    
    
    return print(datastore['RegionChildren:regionchildren']['response']['list']['region'][4]['name'])

def originalhousinginfoaddressCostone(city, state):
    url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18mobi4mvij_2doog&state=%s&city=%s&childtype=neighborhood' % (state, city)
    response = requests.get(url)
    datas = response.text

    jsonString = json.dumps(xmltodict.parse(datas), indent=4)

    with open("testingg.json", 'w') as f:
        f.write(jsonString)
    
    with open("testingg.json") as d:
        datastore = json.load(d)
    
    return(datastore['RegionChildren:regionchildren']['response']['list']['region'][0]['url'])

def originalhousinginfoaddressCosttwo(city, state):
    url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18mobi4mvij_2doog&state=%s&city=%s&childtype=neighborhood' % (state, city)
    response = requests.get(url)
    datas = response.text

    jsonString = json.dumps(xmltodict.parse(datas), indent=4)

    with open("testingg.json", 'w') as f:
        f.write(jsonString)
    
    with open("testingg.json") as d:
        datastore = json.load(d)
    
    return(datastore['RegionChildren:regionchildren']['response']['list']['region'][1]['url'])

def originalhousinginfoaddressCostthree(city, state):
    url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18mobi4mvij_2doog&state=%s&city=%s&childtype=neighborhood' % (state, city)
    response = requests.get(url)
    datas = response.text

    jsonString = json.dumps(xmltodict.parse(datas), indent=4)

    with open("testingg.json", 'w') as f:
        f.write(jsonString)
    
    with open("testingg.json") as d:
        datastore = json.load(d)
    
    return(datastore['RegionChildren:regionchildren']['response']['list']['region'][2]['url'])

def originalhousinginfoaddressCostfour(city, state):
    url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18mobi4mvij_2doog&state=%s&city=%s&childtype=neighborhood' % (state, city)
    response = requests.get(url)
    datas = response.text

    jsonString = json.dumps(xmltodict.parse(datas), indent=4)

    with open("testingg.json", 'w') as f:
        f.write(jsonString)
    
    with open("testingg.json") as d:
        datastore = json.load(d)
    
    return(datastore['RegionChildren:regionchildren']['response']['list']['region'][3]['url'])

def originalhousinginfoaddressCostfive(city, state):
    url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18mobi4mvij_2doog&state=%s&city=%s&childtype=neighborhood' % (state, city)
    response = requests.get(url)
    datas = response.text

    jsonString = json.dumps(xmltodict.parse(datas), indent=4)

    with open("testingg.json", 'w') as f:
        f.write(jsonString)
    
    with open("testingg.json") as d:
        datastore = json.load(d)
   
    return(datastore['RegionChildren:regionchildren']['response']['list']['region'][4]['url'])

def originaldeephouseinfo(street, city, state):
    url = 'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18mobi4mvij_2doog&address=%s&citystatezip=%s+%s'% (street, city, state)
    response = requests.get(url)
    datae = response.text
    
    jsonString = json.dumps(xmltodict.parse(datae), indent=4)

    with open("testingg.json", 'w') as f:
        f.write(jsonString)
    
    with open("testingg.json") as d:
        datastore = json.load(d)
    
    print('Bedrooms =', datastore['SearchResults:searchresults']['response']['results']['result']['bedrooms'])
    print('Bathrooms =', datastore['SearchResults:searchresults']['response']['results']['result']['bathrooms'])
    print('Size = ', datastore['SearchResults:searchresults']['response']['results']['result']['finishedSqft'])
    print('Last Sold Date = ', datastore['SearchResults:searchresults']['response']['results']['result']['lastSoldDate'])
    print('Last Sold Price = $', datastore['SearchResults:searchresults']['response']['results']['result']['lastSoldPrice']['#text'])
    print('Year Built = ',datastore['SearchResults:searchresults']['response']['results']['result']['yearBuilt'])
    print('Highest Amount Value = $',datastore['SearchResults:searchresults']['response']['results']['result']['valuationRange']['high']['#text'])
    print('Lowest Amount Value = $',datastore['SearchResults:searchresults']['response']['results']['result']['valuationRange']['low']['#text'])
    

    return (datastore['SearchResults:searchresults']['response']['results']['result']['address']['street'])

# %%
print('THE HOME FINDER')
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')

question = input("Are you interested in acquiring a home? (Y/N): ").upper

if question != 'Y' or 'N':
    print("Please choose either (Y/N).")

elif question == 'N':
    print("Thank you for using the home finder")

elif question == 'Y':
    print("Okay, Let's start by finding you neighbourhoods in a particlar area. ")
    state = input("Please enter a state you would like to live in (Ex: NY,NC): ")
    city = input("Please enter a city you would like to live in: ")
    print("Here are the top 5 neigbourhoods in that city: ")
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')

    originalhousinginfoaddress(city, state)

    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')

    while True:
        number = (int(input("Please choose either 1,2,3,4 or 5 to find out more about the neighbourhood like the cost to acquire a house in each neigbourhood and where it is on a map in the state: ")))
        if number not in [1, 2, 3, 4, 5]:
            print('Please choose from the list of numbers')
        else:
            if number == 1:
                print('$', originalhousinginfoaddressCostone(city, state))
                break
            elif number == 2:
                print('$', originalhousinginfoaddressCosttwo(city, state))
                break
            elif number == 3:
                print('$', originalhousinginfoaddressCostthree(city, state))
                break
            elif number == 4:
                print('$', originalhousinginfoaddressCostfour(city, state))
                break
            else:
                print('$', originalhousinginfoaddressCostfive(city, state))
                break
    else:
        pass
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')            

while True:
    sell = input("Do you wish to sell your home or acquire more information about the present house you live in? (Y/N): ").upper
    if sell not in ['Y', 'N']:
        print("Plese choose either Y/N!")
    elif sell == 'N':
        print("Thank you for using the Home Finder")
        break
    else:
        break
        print("You are now going to enter the address you wish to find.")
        street = input("Enter the address: ")
        city = input('Enter the city: ')
        state = input('Enter the state: ')
        
        originaldeephouseinfo(street, city, state)

print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')            

while True:
    information = input("Do you wish to find out the nearest parks, churches and schools (Y/N): ").upper
    if information != 'Y' or 'N':
        print("Please choose either Y or N")
    elif information == 'N':
        print('Thank you for using the Home finder.')
    else:
        break
        
        
    
    
              
    

        

    
    

    #datastore['RegionChildren:regionchildren']['response']['list']['region']['url'])

# %%
def originalhousinginfoaddressCostone(city, state):
    url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18mobi4mvij_2doog&state=%s&city=%s&childtype=neighborhood' % (state, city)
    response = requests.get(url)
    datas = response.text

    jsonString = json.dumps(xmltodict.parse(datas), indent=4)

    with open("testingg.json", 'w') as f:
        f.write(jsonString)
    
    with open("testingg.json") as d:
        datastore = json.load(d)
    
    return(datastore['RegionChildren:regionchildren']['response']['list']['region'][0]['url'])

originalhousinginfoaddressCostone('brooklyn', 'ny')
# Out:
# 'http://www.zillow.com/local-info/NY-New-York/Upper-West-Side/r_270958/'

# %%
number = '300'
street = 'ben hogan drive'
city = 'mebane'
state = 'nc'

url = 'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18mobi4mvij_2doog&address=%s+%s&citystatezip=%s+%s'% (number, street, city, state)
response = requests.get(url)
data = response.text
jsonString = json.dumps(xmltodict.parse(data), indent=4)

with open("testingg.json", 'w') as f:
    f.write(jsonString)

with open("testingg.json") as d:
    datastore = json.load(d)
print(datastore)
# Out:
# {'SearchResults:searchresults': {'@xsi:schemaLocation': 'http://www.zillow.com/static/xsd/SearchResults.xsd https://www.zillowstatic.com/vstatic/b20c067/static/xsd/SearchResults.xsd', '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance', '@xmlns:SearchResults': 'http://www.zillow.com/static/xsd/SearchResults.xsd', 'request': {'address': '300 ben hogan drive', 'citystatezip': 'mebane nc'}, 'message': {'text': 'Request successfully processed', 'code': '0'}, 'response': {'results': {'result': {'zpid': '79733971', 'links': {'homedetails': 'https://www.zillow.com/homedetails/300-Ben-Hogan-Dr-Mebane-NC-27302/79733971_zpid/', 'graphsanddata': 'http://www.zillow.com/homedetails/300-Ben-Hogan-Dr-Mebane-NC-27302/79733971_zpid/#charts-and-data', 'mapthishome': 'http://www.zillow.com/homes/79733971_zpid/', 'comparables': 'http://www.zillow.com/homes/comps/79733971_zpid/'}, 'address': {'street': '300 Ben Hogan Dr', 'zipcode': '27302', 'city': 'Mebane', 'state': 'NC', 'latitude': '36.120782', 'longitude': '-79.272728'}, 'FIPScounty': '37001', 'useCode': 'SingleFamily', 'taxAssessmentYear': '2017', 'taxAssessment': '344252.0', 'yearBuilt': '2006', 'lotSizeSqFt': '8843', 'finishedSqFt': '2344', 'bathrooms': '3.5', 'bedrooms': '5', 'lastSoldDate': '01/25/2007', 'lastSoldPrice': {'@currency': 'USD', '#text': '385000'}, 'zestimate': {'amount': {'@currency': 'USD', '#text': '301996'}, 'last-updated': '05/07/2018', 'oneWeekChange': {'@deprecated': 'true'}, 'valueChange': {'@duration': '30', '@currency': 'USD', '#text': '-1491'}, 'valuationRange': {'low': {'@currency': 'USD', '#text': '280856'}, 'high': {'@currency': 'USD', '#text': '323136'}}, 'percentile': '0'}, 'localRealEstate': {'region': {'@name': 'Mebane', '@id': '29105', '@type': 'city', 'zindexValue': '163,700', 'links': {'overview': 'http://www.zillow.com/local-info/NC-Mebane/r_29105/', 'forSaleByOwner': 'http://www.zillow.com/mebane-nc/fsbo/', 'forSale': 'http://www.zillow.com/mebane-nc/'}}}}}}}}

# %%
def google_places(latitude, longitude):
    url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=%s,%s&key=%s' % (
    latitude, longitude, placekey)
    response = requests.get(url)
    location_map = response.json()
    return location_map


# Given a string representing a location, return 2-element tuple
# (latitude, longitude) for that location
#
# See https://developers.google.com/maps/documentation/geocoding/
# for details
#

def geocodeAddress(addressString):
    urlbase = "https://maps.googleapis.com/maps/api/geocode/json?address="
    url = urlbase + quote_plus(addressString) + "&key=" + geopkey
    json_result = requests.get(url)

    if not json_result:
        return None

    json_result = json_result.json()

    if json_result['status'] != "OK":
        print("Status returned from Google geocoder *not* OK: {}".format(json_result['status']))
        return (None, None)
    loc = json_result['results'][0]['geometry']['location']
    return (float(loc['lat']), float(loc['lng']))

def getMapUrl(width, height, lat, lng, zoom):
    urlbase = "http://maps.google.com/maps/api/staticmap?"
    mapid = 'roadmap'
    # mapid='satellite'
    # mapid='terrain'
    # mapid='hybrid'
    args = "center={},{}&maptype={}&zoom={}&size={}x{}&markers=color:red%7Clabel=1%7C{},{}&format=png".format(lat, lng,
                                                                                                              mapid,
                                                                                                              zoom,
                                                                                                              width,
                                                                                                              height,
                                                                                                              lat, lng)
    return urlbase + args


def retrieveMapFromGoogle(addressString, mapFileName):
    lat, lng = geocodeAddress(addressString)
    url = getMapUrl(mapSize, mapSize, lat, lng, zoomLevel)
    urlretrieve(url, mapFileName)

# %%
question = input("Are you interested in acquiring a home? (Y/N): ").upper

if question == 'N':
    print("Thank you for using the home finder")
    
if question is 'Y':
    print('hdsbhcjhcjdhcjdnbhj')
    print('hjshxjnhjxcnx')
# Out:
# Are you interested in acquiring a home? (Y/N): N

# %%
print(help(str.upper))
